# %%
# %run run.py
# Out:
# Using TensorFlow backend.
# > Loading data...
# > Data Loaded. Compiling...
# > Compilation Time :  0.023079395294189453
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
# 3523/3523 [==============================] - 5s - loss: 0.0025 - val_loss: 8.7659e-04
# Training duration (s) :  23.650482654571533
